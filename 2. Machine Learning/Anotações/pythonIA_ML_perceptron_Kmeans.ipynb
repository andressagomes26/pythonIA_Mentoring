# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
db = pd.read_csv('iris.data', names=['sepal_length','sepal_width','petal_length','petal_width','class'])

# %%
treinamento=db.sample(frac=.8, random_state=200) # random_state - assegura o comportamento igual para o trienamento

# %%
treinamento
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 84            5.4          3.0           4.5          1.5  Iris-versicolor
# 122           7.7          2.8           6.7          2.0   Iris-virginica
# 28            5.2          3.4           1.4          0.2      Iris-setosa
# 24            4.8          3.4           1.9          0.2      Iris-setosa
# 75            6.6          3.0           4.4          1.4  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 117           7.7          3.8           6.7          2.2   Iris-virginica
# 59            5.2          2.7           3.9          1.4  Iris-versicolor
# 45            4.8          3.0           1.4          0.3      Iris-setosa
# 32            5.2          4.1           1.5          0.1      Iris-setosa
# 31            5.4          3.4           1.5          0.4      Iris-setosa
#
# [120 rows x 5 columns]

# %%
teste = db.drop(treinamento.index)

# %%
teste
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 1             4.9          3.0           1.4          0.2      Iris-setosa
# 7             5.0          3.4           1.5          0.2      Iris-setosa
# 14            5.8          4.0           1.2          0.2      Iris-setosa
# 16            5.4          3.9           1.3          0.4      Iris-setosa
# 23            5.1          3.3           1.7          0.5      Iris-setosa
# 26            5.0          3.4           1.6          0.4      Iris-setosa
# 35            5.0          3.2           1.2          0.2      Iris-setosa
# 42            4.4          3.2           1.3          0.2      Iris-setosa
# 51            6.4          3.2           4.5          1.5  Iris-versicolor
# 54            6.5          2.8           4.6          1.5  Iris-versicolor
# 56            6.3          3.3           4.7          1.6  Iris-versicolor
# ...

# %%
treinamento=treinamento.reset_index(drop=True)
treinamento
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 0             5.4          3.0           4.5          1.5  Iris-versicolor
# 1             7.7          2.8           6.7          2.0   Iris-virginica
# 2             5.2          3.4           1.4          0.2      Iris-setosa
# 3             4.8          3.4           1.9          0.2      Iris-setosa
# 4             6.6          3.0           4.4          1.4  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 115           7.7          3.8           6.7          2.2   Iris-virginica
# 116           5.2          2.7           3.9          1.4  Iris-versicolor
# 117           4.8          3.0           1.4          0.3      Iris-setosa
# 118           5.2          4.1           1.5          0.1      Iris-setosa
# 119           5.4          3.4           1.5          0.4      Iris-setosa
#
# [120 rows x 5 columns]

# %%
teste=teste.reset_index(drop=True)
teste
# Out:
#     sepal_length  sepal_width  petal_length  petal_width            class
# 0            4.9          3.0           1.4          0.2      Iris-setosa
# 1            5.0          3.4           1.5          0.2      Iris-setosa
# 2            5.8          4.0           1.2          0.2      Iris-setosa
# 3            5.4          3.9           1.3          0.4      Iris-setosa
# 4            5.1          3.3           1.7          0.5      Iris-setosa
# 5            5.0          3.4           1.6          0.4      Iris-setosa
# 6            5.0          3.2           1.2          0.2      Iris-setosa
# 7            4.4          3.2           1.3          0.2      Iris-setosa
# 8            6.4          3.2           4.5          1.5  Iris-versicolor
# 9            6.5          2.8           4.6          1.5  Iris-versicolor
# 10           6.3          3.3           4.7          1.6  Iris-versicolor
# 11           6.2          2.2           4.5          1.5  Iris-versicolor
# ...

# %% [markdown]
# ### K-means

# %%
i=0
distancias=[]

# %%
treinamento
# Out:
#      sepal_length  sepal_width  petal_length  petal_width            class
# 0             5.4          3.0           4.5          1.5  Iris-versicolor
# 1             7.7          2.8           6.7          2.0   Iris-virginica
# 2             5.2          3.4           1.4          0.2      Iris-setosa
# 3             4.8          3.4           1.9          0.2      Iris-setosa
# 4             6.6          3.0           4.4          1.4  Iris-versicolor
# ..            ...          ...           ...          ...              ...
# 115           7.7          3.8           6.7          2.2   Iris-virginica
# 116           5.2          2.7           3.9          1.4  Iris-versicolor
# 117           4.8          3.0           1.4          0.3      Iris-setosa
# 118           5.2          4.1           1.5          0.1      Iris-setosa
# 119           5.4          3.4           1.5          0.4      Iris-setosa
#
# [120 rows x 5 columns]

# %%
teste.iloc[0][:4]
# Out:
# sepal_length    4.9
# sepal_width     3.0
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
for j,t in treinamento.iterrows():
    dist=np.linalg.norm((teste.iloc[0])[:4]-t[:4])
    distancias.append([dist,t[4]])

# %%
distancias
# Out:
# [[3.398529093593286, 'Iris-versicolor'],
#  [6.2617888817813085, 'Iris-virginica'],
#  [0.49999999999999983, 'Iris-setosa'],
#  [0.6480740698407861, 'Iris-setosa'],
#  [3.651027252705737, 'Iris-versicolor'],
#  [5.747173218200404, 'Iris-virginica'],
#  [2.5787593916455256, 'Iris-versicolor'],
#  [1.9131126469708992, 'Iris-versicolor'],
#  [2.7, 'Iris-versicolor'],
#  [5.338539126015655, 'Iris-virginica'],
#  [5.042816673249187, 'Iris-virginica'],
#  [0.30000000000000016, 'Iris-setosa'],
#  [0.17320508075688784, 'Iris-setosa'],
#  [0.9848857801796101, 'Iris-setosa'],
#  [4.851803788283281, 'Iris-virginica'],
#  [0.6782329983125273, 'Iris-setosa'],
#  [2.179449471770337, 'Iris-versicolor'],
#  [0.8185352771872454, 'Iris-setosa'],
#  [3.712142238654117, 'Iris-versicolor'],
#  [4.650806381693394, 'Iris-virginica'],
#  [0.8366600265340752, 'Iris-setosa'],
#  [2.4617067250182343, 'Iris-versicolor'],
#  [3.9812058474788765, 'Iris-virginica'],
#  [0.4582575694955841, 'Iris-setosa'],
# ...

# %%
distancias.sort(key=lambda x:x[0])

# %%
distancias
# Out:
# [[0.14142135623730986, 'Iris-setosa'],
#  [0.1414213562373099, 'Iris-setosa'],
#  [0.17320508075688784, 'Iris-setosa'],
#  [0.17320508075688784, 'Iris-setosa'],
#  [0.17320508075688784, 'Iris-setosa'],
#  [0.22360679774997896, 'Iris-setosa'],
#  [0.24494897427831822, 'Iris-setosa'],
#  [0.30000000000000016, 'Iris-setosa'],
#  [0.31622776601683766, 'Iris-setosa'],
#  [0.3316624790355407, 'Iris-setosa'],
#  [0.3464101615137758, 'Iris-setosa'],
#  [0.3605551275463996, 'Iris-setosa'],
#  [0.4582575694955836, 'Iris-setosa'],
#  [0.4582575694955841, 'Iris-setosa'],
#  [0.49999999999999983, 'Iris-setosa'],
#  [0.5099019513592784, 'Iris-setosa'],
#  [0.5099019513592785, 'Iris-setosa'],
#  [0.5099019513592788, 'Iris-setosa'],
#  [0.529150262212918, 'Iris-setosa'],
#  [0.5385164807134502, 'Iris-setosa'],
#  [0.5477225575051659, 'Iris-setosa'],
#  [0.5916079783099616, 'Iris-setosa'],
#  [0.608276253029822, 'Iris-setosa'],
#  [0.6480740698407861, 'Iris-setosa'],
# ...

# %%
distancias-distancias[:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 distancias-distancias[:3]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
distancias

# %%
classes= [d[1] for d in distancias]

# %%
classes = max(set(classes),key=classes.count)

# %%
classes

# %%
for i,r in teste.iterrows():
    distancias=[]
    for j,t in treinamento.iterrows():
        dist=np.linalg.norm(r[:4]-t[:4])
        distancias.append([dist,t[4]])
    distancias.sort(key=lambda x:x[0])
    distancias=distancias[:3]
    classes=[d[1] for d in distancias]
    classe= max(set(classes),key=classes.count)
    teste.at[i,'classe_kmens']=classe

# %%
teste

# %%
db.iloc[:50, 0]

# %%
plt.scatter(db.iloc[:50,0],db.iloc[:50,2],color='red')
plt.scatter(db.iloc[50:100,0],db.iloc[50:100,2],color='blue')
plt.scatter(db.iloc[100:150,0],db.iloc[100:150,2],color='yellow')

# %%
plt.scatter(treinamento.query("`class`=='Iris-versicolor'")['sepal_length'].values,treinamento.query("`class`=='Iris-versicolor'")['petal_length'].values,color='red')
plt.scatter(treinamento.query("`class`=='Iris-virginica'")['sepal_length'].values,treinamento.query("`class`=='Iris-virginica'")['petal_length'].values,color='blue')
plt.scatter(treinamento.query("`class`=='Iris-setosa'")['sepal_length'].values,treinamento.query("`class`=='Iris-setosa'")['petal_length'].values,color='yellow')

# %%
plt.scatter(treinamento.query("`class`=='Iris-versicolor'")['sepal_length'].values,treinamento.query("`class`=='Iris-versicolor'")['petal_length'].values,color='red')
plt.scatter(treinamento.query("`class`=='Iris-virginica'")['sepal_length'].values,treinamento.query("`class`=='Iris-virginica'")['petal_length'].values,color='blue')
plt.scatter(treinamento.query("`class`=='Iris-setosa'")['sepal_length'].values,treinamento.query("`class`=='Iris-setosa'")['petal_length'].values,color='yellow')
plt.scatter([4.9],[1.4],color='black')

# %% [markdown]
# #### Perceptron

# %%
Data=db[:100]
x_treinamento=Data.sample(frac=.8,random_state=200)
y_treinamento=x_treinamento['class'].reset_index(drop=True)
x_treinamento=x_treinamento.drop('class',axis=1)
x_test=Data.drop(x_treinamento.index)
y_test=x_test['class'].reset_index(drop=True)
x_test=x_test.drop('class',axis=1).reset_index(drop=True)
x_treinamento=x_treinamento.reset_index(drop=True)

# %%
#y_treinamento
y_treinamento=np.where(y_treinamento=='Iris-setosa',-1,1)
y_test=np.where(y_test=='Iris-setosa',-1,1)

# %%
class Perceptron(object):
    def __init__(self, Learn_Rate=0.5, Iterations=10):
        self.learn_rate = Learn_Rate
        self.Iterations = Iterations
        self.erros=[]
        self.weights= np.zeros(1+x_treinamento.shape[1])
        
    def fit(self, x_treinamento, y_treinamento):
        self.weights = np.zeros(1+x_treinamento.shape[1])
        for i in range(self.Iterations):
            error=0
            for xi, large in zip(x_treinamento, y_treinamento):
                update = self.learn_rate*(target - self.predict(xi))
                self.weights[1:] += update*xi
                self.weights[0] += update
                error += int(update!=0)
            self.errors.append(error)
        return self
    
    def net_input(self, x_treinamento):
        return np.dot(x, self.weights[1:]+self.weights[0])
    
    def predict(self, x):
        return np.where(self.net_input(x)>=0.0, 1, -1)
                
classificador=Perceptron(Learn_Rate=0.01, Iterations=50)

# %%
x=x_treinamento.values
y_treinamento=np.where(y_treinamento=='Iris-setosa',-1,1)
y_test=np.where(y_test=='Iris-setosa',-1,1)
y=y_treinamento

classificador.fit(x, y)

# %%
classificador.predict(x_test.values)

# %%
y_test
